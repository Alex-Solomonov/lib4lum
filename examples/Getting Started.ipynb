# %% [markdown]
# # Getting Started

# %% [markdown]
# ## Installation

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating workspace

# %%
from lib4lum import deploy
# deploy.run()

# %% [markdown]
# NB: Be aware calling run once again will rewrite default file

# %% [markdown]
# ### Load parameters

# %%
params = deploy.read_config()
print(params)
# Out:
# {'SOLVER': {'wavelength': 1e-09}, 'STRUCTURE': {'size': 12, 'period': 4.25e-07}, 'UNIT CELL': {'h_disk': 1.5e-07, 'h_spacer': 1.5e-07}, 'BOX': {'z_min': -3e-09}}

# %% [markdown]
# params can be changed here

# %%
params['SOLVER']['wavelength'] = 850e-09
print(params)
# Out:
# {'SOLVER': {'wavelength': 8.5e-07}, 'STRUCTURE': {'size': 12, 'period': 4.25e-07}, 'UNIT CELL': {'h_disk': 1.5e-07, 'h_spacer': 1.5e-07}, 'BOX': {'z_min': -3e-09}}

# %% [markdown]
# ### Seeds

# %%
from lib4lum import folder_seed_generator

folder_seed_generator.generate_seed(eta = 0, realizations = 1)

# %% [markdown]
# ## Work with phases

# %%
from lib4lum import phase_profiles

# %%
phase, X, Y = phase_profiles.lens_profile(2e-06, 
                            params['SOLVER']['wavelength'], 
                            params['STRUCTURE']['period'],
                            params['STRUCTURE']['size'])

# %%
fig, ax = plt.subplots(1,1)
ax.imshow(phase)
